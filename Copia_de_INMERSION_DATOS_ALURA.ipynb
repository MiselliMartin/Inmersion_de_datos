# %% [markdown]
# <a href="https://colab.research.google.com/github/MiselliMartin/Inmersion_de_datos/blob/main/Copia_de_INMERSION_DATOS_ALURA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bienvenido a nuestro primer encuentro de inmersión de datos.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importamos biblioteca pandas
import pandas as pd
#leemos el archivo csv
inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/inmuebles_bogota.csv') 
#.head se utiliza para imprimir los primeros valores de el dataset, por default los primeros 5
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
#devuelve la forma del dataset, nfilas y ncolumnas
inmuebles.shape
# Out:
# (9520, 8)

# %%
#información sobre las columnas
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
#generamos un dict
columnas = {'Baños':'Banos','Área':'Area'}
#usamos nuestro dict columans para renombrar el dataset
inmuebles = inmuebles.rename(columns=columnas)
#sample es utilizado para obtener una muestra al azar
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3647  Apartamento            Apartamento en venta en Santa Fe             1
# 4852  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 2448         Casa                    Casa en venta en Kennedy             8
# 647   Apartamento       Apartamento en venta en Santa Barbara             2
# 1178  Apartamento            Apartamento en venta en Fontibón             1
# 8479  Apartamento                Apartamento en venta en Suba             3
# 3524  Apartamento            Apartamento en venta en Engativa             2
# 9127  Apartamento     Apartamento en venta en Chico Reservado             3
# 1519         Casa                       Casa en venta en Suba             3
# 5163  Apartamento         Apartamento en venta en Los Rosales             3
#
#       Banos  Area              Barrio                                     UPZ  \
# ...

# %%
#info del dataset
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
#devuelve la información ubicada en un índice específico, en este caso el índice 300
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
#develve la info de un grupo de índices, en este caso del índice 300 al 304
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
#devuelve atributo específico de índice específico
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
#el tipo de dato que devuelve es también un dataset
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
#.mean() calcula el promedio (la media)
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 6353  Apartamento            Apartamento en venta en Fontibón             3
# 2183  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 6512  Apartamento             Apartamento en venta en Mazuren             3
# 5133  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 3289  Apartamento            Apartamento en venta en La Salle             1
# ...           ...                                         ...           ...
# 2943  Apartamento                Apartamento en venta en Bosa             3
# 7297  Apartamento             Apartamento en venta en Tintala             3
# 3047         Casa                    Casa en venta en Kennedy             6
# 4193  Apartamento        Apartamento en venta en Los Mártires             3
# 5666  Apartamento             Apartamento en venta en Modelia             3
#
# ...

# %%
#consultamos qué elementos tienen en Barrio el valor 'Chico Reservado', devuelve booleano
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
#La suma de los 'True'
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
#guardamos en una variable los elementos con el valor 'Chico Reservado' en el atributo 'Barrio'
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
#Generamos un nuevo dataset con los elementos ubicados en chico_reservado filtrando el dataset original y lo imprimimos
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
#Área promedio de Chico Reservado
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
#Las casas de Chico Reservado están por debajo de promedio del dataset
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
#Cantidad de valores diferentes del atributo 'Barrio'
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
#Valores diferentes del atributo 'Barrio' y la cantidad, imprimiendo el head descubrimos los barrios con más casas en venta
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
#Cantidad de valores diferentes de 'UPZ'
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
#Generamos un histograma de la cantidad de casas por barrio
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
#Histograma de los 10 valores más altos
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **Desafío**
#
#
# 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
#
# 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
#Calculamos la media de área por barrio, primero agrupamos los inmuebles según su valor en el atributo 'Barrio' y luego utilizamos los valores guardados en área para calcular la media
medias_por_barrio = inmuebles.groupby(['Barrio'])['Area'].mean()
"Medias:", medias_por_barrio.nlargest(10)
# Out:
# ('Medias:',
#  Barrio
#  Modelia                  4316.750000
#  Libertador                642.000000
#  Bosa Piamonte             400.000000
#  La Soledad                378.625000
#  Restrepo                  336.500000
#  Santa Librada             328.000000
#  Las Ferias                320.000000
#  Santa Ana                 309.375000
#  Veraguas                  302.666667
#  Bellavista Occidental     286.200000
#  Name: Area, dtype: float64)

# %%
medias_por_barrio.nlargest(10).plot.bar(title='Área promedio de los 10 mayores valores', xlabel='Barrio', ylabel='Área')
# Out:
# <Axes: title={'center': 'Área promedio de los 10 mayores valores'}, xlabel='Barrio', ylabel='Área'>

# %%
#Descubrimos que el área de Modelia es extrañamente alta y calculamos sus 5 valores de área más grande
barrio_modelia = (inmuebles.Barrio == 'Modelia')
inmuebles_barrio_modelia = (inmuebles[barrio_modelia])
inmuebles_barrio_modelia.Area.nlargest(5)
# Out:
# 7073    166243
# 8562       400
# 2147       320
# 4913       320
# 4914       320
# Name: Area, dtype: int64

# %%
inmuebles_barrio_modelia.Area.median()
# Out:
# 155.5

# %%
#Encontramos que la información del índice 7073 es érronea, o anómala
inmuebles.iloc[7073]
# Out:
# Tipo                                Casa
# Descripcion     Casa en venta en Modelia
# Habitaciones                           4
# Banos                                  3
# Area                              166243
# Barrio                           Modelia
# UPZ                             Fontibón
# Valor                      $ 850.000.000
# Name: 7073, dtype: object

# %%
media_baño = inmuebles.Banos.mean()
media_habitaciones = inmuebles.Habitaciones.mean()
"Media de baño:", media_baño, "Media de habitaciones:", media_habitaciones
# Out:
# ('Media de baño:',
#  2.4478991596638657,
#  'Media de habitaciones:',
#  3.072478991596639)

# %%
max_baño = inmuebles.Banos.max()
max_habitaciones = inmuebles.Habitaciones.max()
"Max de baño:", max_baño, "Max de habitaciones:", max_habitaciones
# Out:
# ('Max de baño:', 9, 'Max de habitaciones:', 110)

# %%
#Vemos que hay una casa con 110 habitaciones y buscamos su índice
ind_max_hab = inmuebles.Habitaciones.idxmax()
ind_max_hab
# Out:
# 897

# %%
#Imprimimos la información de la casa con un valor érroneo
inmuebles.iloc[ind_max_hab]
# Out:
# Tipo                                 Casa
# Descripcion     Casa en venta en La Uribe
# Habitaciones                          110
# Banos                                   2
# Area                                  110
# Barrio                           La Uribe
# UPZ                               Usaquén
# Valor                       $ 480.000.000
# Name: 897, dtype: object

# %%
#Buscamos la casa con más baños para comprobar los datos
ind_max_bañ = inmuebles.Banos.idxmax()
ind_max_bañ
# Out:
# 1955

# %%
#Descubrimos que NO hay una incongruencia en los datos, por lo menos a primera vista.
inmuebles.iloc[ind_max_bañ]
# Out:
# Tipo                                         Local
# Descripcion       Local en venta en Quinta Camacho
# Habitaciones                                    16
# Banos                                            9
# Area                                          1050
# Barrio                              Quinta Camacho
# UPZ             CHAPINERO: Chicó Lago + El Refugio
# Valor                              $ 5.299.999.744
# Name: 1955, dtype: object

# %%
inmuebles['Valor_millon'] = inmuebles['Valor']

# %%
inmuebles['Valor_millon'] = inmuebles['Valor_millon'].str.replace('[^0-9\.]', '', regex = True)

# %%
inmuebles['Valor_millon'] = inmuebles['Valor_millon'].str.replace('.', '', regex = True)

# %%
inmuebles['Valor_millon'] = inmuebles['Valor_millon'].str.replace('$', '', regex = True)

# %%
inmuebles['Valor_millon'] = inmuebles['Valor_millon'].str.replace(' ', '', regex = True)

# %%
inmuebles['Valor_millon'] = inmuebles['Valor_millon'].astype(float)

# %%
inmuebles['Valor_millon'] = inmuebles['Valor_millon'] / 1000000

# %%
inmuebles.Valor_millon.mean()
# Out:
# 602.0623535276261

# %%
idx_valor_max = inmuebles.Valor_millon.idxmax()

# %%
idx_valor_min = inmuebles.Valor_millon.idxmin()

# %%
inmuebles.iloc[idx_valor_max]
# Out:
# Tipo                                Edificio
# Descripcion     Edificio en venta en Usaquén
# Habitaciones                              12
# Banos                                      7
# Area                                    1664
# Barrio                               Usaquén
# UPZ                                  Usaquén
# Valor                       $ 16.000.000.000
# Valor_millon                         16000.0
# Name: 5234, dtype: object

# %%
inmuebles.iloc[idx_valor_min]
# Out:
# Tipo                                      Oficina/Consultorio
# Descripcion     Oficina/Consultorio en venta en La Candelaria
# Habitaciones                                                1
# Banos                                                       2
# Area                                                       24
# Barrio                                          La Candelaria
# UPZ                                             La Candelaria
# Valor                                            $ 60.000.000
# Valor_millon                                             60.0
# Name: 4847, dtype: object

# %%
inmuebles.groupby(['Barrio'])['Valor_millon'].mean().nlargest(5).plot.bar(title='Valores por barrio', ylabel='Valor')
# Out:
# <Axes: title={'center': 'Valores por barrio'}, xlabel='Barrio', ylabel='Valor'>

# %%
inmuebles.mode()
# Out:
#           Tipo                      Descripcion  Habitaciones  Banos  Area  \
# 0  Apartamento  Apartamento en venta en Usaquén             3      2    47
#
#     Barrio      UPZ          Valor  Valor_millon
# 0  Usaquén  Usaquén  $ 450.000.000         450.0

# %%
inmuebles.select_dtypes(include='number').median()
# Out:
# Habitaciones      3.0000
# Banos             2.0000
# Area             80.0000
# Valor_millon    409.1825
# dtype: float64

# %%
inmuebles.select_dtypes(include='number').mean()
# Out:
# Habitaciones      3.072479
# Banos             2.447899
# Area            146.664706
# Valor_millon    602.062354
# dtype: float64

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Valor_millon
# count   9520.000000  9520.000000    9520.000000   9520.000000
# mean       3.072479     2.447899     146.664706    602.062354
# std        2.049856     1.255314    1731.379622    704.602062
# min        1.000000     0.000000       2.000000     60.000000
# 25%        2.000000     2.000000      57.000000    250.000000
# 50%        3.000000     2.000000      80.000000    409.182500
# 75%        3.000000     3.000000     135.000000    680.000000
# max      110.000000     9.000000  166243.000000  16000.000000

# %%
inmuebles.describe().round(2)
# Out:
#        Habitaciones    Banos       Area  Valor_millon
# count       9520.00  9520.00    9520.00       9520.00
# mean           3.07     2.45     146.66        602.06
# std            2.05     1.26    1731.38        704.60
# min            1.00     0.00       2.00         60.00
# 25%            2.00     2.00      57.00        250.00
# 50%            3.00     2.00      80.00        409.18
# 75%            3.00     3.00     135.00        680.00
# max          110.00     9.00  166243.00      16000.00

# %%
sum(inmuebles.Valor_millon) / sum(inmuebles.Area)
# Out:
# 4.105025472253497

# %%
4.105025472253497*sum(inmuebles.Area) == sum(inmuebles.Valor_millon)
# Out:
# True

# %% [markdown]
# #**Aula 2**

# %%
inmuebles.sample(5)
# Out:
#              Tipo                           Descripcion  Habitaciones  Banos  \
# 3851         Casa              Casa en venta en Kennedy             2      1
# 2773  Apartamento      Apartamento en venta en Cedritos             3      2
# 1876  Apartamento  Apartamento en venta en Los Mártires             3      1
# 700   Apartamento       Apartamento en venta en Kennedy             3      1
# 1084  Apartamento   Apartamento en venta en La Soledad              3      2
#
#       Area        Barrio              UPZ          Valor  Valor_millon
# 3851    51       Kennedy  Kennedy Central  $ 135.000.000         135.0
# 2773    80      Cedritos          Usaquén  $ 350.000.000         350.0
# 1876    59  Los Mártires        La Sabana  $ 290.000.000         290.0
# 700     49       Kennedy  Kennedy Central  $ 175.000.000         175.0
# 1084   110   La Soledad       Teusaquillo  $ 485.000.000         485.0

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Valor_millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 669.5+ KB

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Valor_millon
# count       9520.00 9520.00   9520.00       9520.00
# mean           3.07    2.45    146.66        602.06
# std            2.05    1.26   1731.38        704.60
# min            1.00    0.00      2.00         60.00
# 25%            2.00    2.00     57.00        250.00
# 50%            3.00    2.00     80.00        409.18
# 75%            3.00    3.00    135.00        680.00
# max          110.00    9.00 166243.00      16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor  Valor_millon
# 897  Usaquén  $ 480.000.000        480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor  Valor_millon
# 8401     2  San Cristobal  Sosiego  $ 180.000.000        180.00

# %%
inmuebles['Valor_millon'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Valor_millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/valor_inmuebles.png',format='png')
plt.show()

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3412         Casa                  Casa en venta en Normandia             3
# 15           Casa         Casa en venta en Zona Noroccidental             3
# 8091  Apartamento            Apartamento en venta en Verbenal             2
# 765   Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4630         Casa             Casa en venta en Antonio Nariño             5
#
#       Banos  Area              Barrio  \
# 3412      3   319           Normandia
# 15        4   300  Zona Noroccidental
# 8091      1    38            Verbenal
# 765       2    58  Zona Noroccidental
# 4630      4   364      Antonio Nariño
#
#                                              UPZ            Valor  \
# 3412  ENGATIVÁ: Santa Cecilia + Jardín  Botánico  $ 1.400.000.000
# 15            CHAPINERO: Pardo Rubio + Chapinero  $ 2.519.000.000
# 8091                                    Verbenal    $ 180.000.000
# ...

# %% [markdown]
# **Desafíos**
#
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)
#
# 2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
inmuebles.groupby('Barrio').agg({'Valor_millon': 'sum', 'Area': 'sum'}).assign(precio_promedio_m2=lambda x: x['Valor_millon'] / x['Area'])
# Out:
#                     Valor_millon    Area  precio_promedio_m2
# Barrio
# Alameda                   580.00      97                5.98
# Alhambra                12790.00    3237                3.95
# Andes Norte              4967.00     874                5.68
# Antonio Nariño          22042.65    7827                2.82
# Barrancas                4712.00    1053                4.47
# ...                          ...     ...                 ...
# Villa Maria              5237.00    2693                1.94
# Villas De Granada        6210.62    1905                3.26
# Villemar                 5469.00    1384                3.95
# Zona Franca               160.00      54                2.96
# Zona Noroccidental     544453.06  119084                4.57
#
# [149 rows x 3 columns]

# %%
inmuebles.sample(3)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 4504  Apartamento  Apartamento en venta en Barrios Unidos             3
# 1725  Apartamento        Apartamento en venta en Engativa             2
# 9321         Casa                   Casa en venta en Suba             6
#
#       Banos  Area          Barrio        UPZ            Valor  Valor_millon
# 4504      3    60  Barrios Unidos  Los Andes    $ 195.500.000        195.50
# 1725      2    53        Engativa   Engativá    $ 331.500.000        331.50
# 9321      5   296            Suba       Suba  $ 1.300.000.000       1300.00

# %%
inmuebles.Tipo.value_counts()
# Out:
# Apartamento            7327
# Casa                   2043
# Oficina/Consultorio      60
# Local                    38
# Edificio                 22
# Bodega                   13
# Finca                    11
# Lote                      6
# Name: Tipo, dtype: int64

# %%
plt.figure(figsize=(12,8))

g = sns.histplot(x="Valor_millon",
                 kde=True,
                 hue="Tipo",
                 hue_order=["Apartamento", "Casa", "Oficina/Consultorio"],
                 palette="dark",
                 data=inmuebles)

g.set_title("Precio inmuebles Bogotá con 3 parametros de 'Tipo'")

plt.setp(g.get_legend().get_title(), fontsize=15)
plt.setp(g.get_legend().get_texts(), fontsize=10)

plt.xlim((50, 1000))
g.set_xlabel("Valor en millones)")
g.set_ylabel("Frecuecia")

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.savefig('/content/drive/MyDrive/frecuencias_dia_2.png',format='png')
plt.show()

# %%
inmuebles['Valor_m_x_a'] = inmuebles.Valor_millon / inmuebles.Area
inmuebles['Valor_m_x_a'] = inmuebles.Valor_m_x_a.sort_values(ascending = False)
inmuebles.Valor_m_x_a
# Out:
# 0      5.14
# 1      3.94
# 2      7.78
# 3      5.78
# 4      7.58
#        ...
# 9515   4.14
# 9516   6.70
# 9517   2.35
# 9518   1.83
# 9519   2.79
# Name: Valor_m_x_a, Length: 9520, dtype: float64

# %%
promedio_valor_m_x_a = inmuebles['Valor_m_x_a'].mean()

# %%
plt.figure(figsize=(15,8))

top_i_x_m_x_a = inmuebles.sort_values(by='Valor_m_x_a', ascending=False).head(20)

graph = sns.barplot(x="Barrio",
                y="Valor_m_x_a",
                palette="dark",
                data=top_i_x_m_x_a)
                
graph.set_title ("Valor de metro cuadrado por barrio")
graph.set_ylabel ("Valor por metro cuadrado de área")
graph.set_xlabel ("Barrio")
graph.axhline(y=promedio_valor_m_x_a, linestyle="--", color="green")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.savefig('/content/drive/MyDrive/m2_x_barrio.png',format='png')

plt.show()

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Valor_millon  Valor_m_x_a
# Barrio
# Alameda                        3      2      97        580.00         5.98
# Alhambra                      51     50    3237      12790.00        73.56
# Andes Norte                   21     20     874       4967.00        42.35
# Antonio Nariño               207    120    7827      22042.65       169.47
# Barrancas                     43     32    1053       4712.00        66.24
# ...                          ...    ...     ...           ...          ...
# Villa Maria                   61     48    2693       5237.00        26.58
# Villas De Granada             76     51    1905       6210.62        69.71
# Villemar                      53     37    1384       5469.00        71.81
# Zona Franca                    2      1      54        160.00         2.96
# Zona Noroccidental          2778   2204  119084     544453.06      4049.16
#
# [149 rows x 5 columns]

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Valor_millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Valor_millon  Valor_m_x_a  \
# Barrio
# Alameda                        3      2      97        580.00         5.98
# Alhambra                      51     50    3237      12790.00        73.56
# Andes Norte                   21     20     874       4967.00        42.35
# Antonio Nariño               207    120    7827      22042.65       169.47
# Barrancas                     43     32    1053       4712.00        66.24
# ...                          ...    ...     ...           ...          ...
# Villa Maria                   61     48    2693       5237.00        26.58
# Villas De Granada             76     51    1905       6210.62        69.71
# Villemar                      53     37    1384       5469.00        71.81
# Zona Franca                    2      1      54        160.00         2.96
# Zona Noroccidental          2778   2204  119084     544453.06      4049.16
#
#                     Valor_m2_Barrio
# Barrio
# ...

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['precio_m2_x_barrio'] = inmuebles['Barrio']
inmuebles['precio_m2_x_barrio'] = inmuebles['precio_m2_x_barrio'].map(m2_barrio)

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Valor_millon  \
# 0               Alameda             3      2      97        580.00
# 1              Alhambra            51     50    3237      12790.00
# 2           Andes Norte            21     20     874       4967.00
# 3        Antonio Nariño           207    120    7827      22042.65
# 4             Barrancas            43     32    1053       4712.00
# ..                  ...           ...    ...     ...           ...
# 144         Villa Maria            61     48    2693       5237.00
# 145   Villas De Granada            76     51    1905       6210.62
# 146            Villemar            53     37    1384       5469.00
# 147         Zona Franca             2      1      54        160.00
# 148  Zona Noroccidental          2778   2204  119084     544453.06
#
#      Valor_m_x_a  Valor_m2_Barrio
# 0           5.98             5.98
# 1          73.56             3.95
# 2          42.35             5.68
# ...

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Valor_millon  \
# 5        Barrios Unidos          1525   1196   87799     259877.76
# 10                 Bosa          1743    789   34879      93400.56
# 22             Cedritos          1458   1348   53711     270027.73
# 24            Chapinero           892    913   81248     372130.93
# 50             Engativa          1676   1077   59808     172711.73
# 63              Kennedy          2151   1233   61475     207963.65
# 125       Santa Barbara          1073   1162   54693     320097.80
# 132                Suba          1497   1202   61615     266406.04
# 138             Usaquén          3109   3044  148121     837710.36
# 148  Zona Noroccidental          2778   2204  119084     544453.06
#
#      Valor_m_x_a  Valor_m2_Barrio
# 5        2070.61             2.96
# 10       1654.36             2.68
# 22       2853.23             5.03
# 24       2466.03             4.58
# 50       1795.71             2.89
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
ax.axhline(y=datos_barrio['Valor_m2_Barrio'].mean(), linestyle="--", color="green")

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m_x_a", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Identificación (Capítulo A).csv', sep = ';',encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Datos de la vivenda y su entorno (Capítulo B).csv', sep = ';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Composición del hogar y demografía (Capítulo E).csv', sep = ';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Educación (Capítulo H).csv', sep = ';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Fuerza de trabajo (Capítulo K).csv', sep = ';',encoding='latin-1')
# Out:
# <ipython-input-87-8c0db24b340f>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';',encoding='latin-1')
# <ipython-input-87-8c0db24b340f>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Composición del hogar y demografía (Capítulo E).csv', sep = ';',encoding='latin-1')
# <ipython-input-87-8c0db24b340f>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/Educación (Capítulo H).csv', sep = ';',encoding='latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-90-a8281422ec17>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %%
datos_dane.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004346.00    11  11001      1           3.00         Santa Fe
# 2  3004346.00    11  11001      1           3.00         Santa Fe
# 3  3004346.00    11  11001      1           3.00         Santa Fe
# 4  3004347.00    11  11001      1          14.00     Los Mártires
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 4          37.00                            Santa Isabel     11001162
#
#                            NOMBRE_ESTRATO  ... NPCEP22A  NPCEP24  NPCEP24A  \
# ...

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    CONJUNTO_CERRADO  FABRICAS_CERCA  TERMINALES_BUS  BARES_DISCO  \
# 0                 1               2               2            2
# 1                 1               2               2            2
# 2                 2               2               2            2
# 3                 1               2               2            2
# 4                 1               2               2            2
#
#    OSCURO_PELIGROSO  RUIDO  INSEGURIDAD  ...  COMO_NIVEL_VIDA  \
# ...

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos.loc[datos.NOMBRE_ESTRATO == '20 de Julio']
# Out:
#      NOMBRE_ESTRATO  CONJUNTO_CERRADO  INSEGURIDAD  TERMINALES_BUS  \
# 513     20 de Julio                 0            0               0
# 706     20 de Julio                 0            1               0
# 707     20 de Julio                 0            1               0
# 708     20 de Julio                 0            1               0
# 709     20 de Julio                 0            1               0
# ...             ...               ...          ...             ...
# 8372    20 de Julio                 0            1               0
# 8751    20 de Julio                 0            0               0
# 8752    20 de Julio                 0            1               0
# 8783    20 de Julio                 0            1               1
# 9287    20 de Julio                 0            1               0
#
#       BARES_DISCO  RUIDO  OSCURO_PELIGROSO  SALARIO_MES  TIENE_ESCRITURA  \
# 513             0      1                 0        98.00             1.00
# ...

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Valor_millon              9520 non-null   float64
#  9   Valor_m_x_a               9520 non-null   float64
#  10  precio_m2_x_barrio        9520 non-null   float64
#  11  CONJUNTO_CERRADO          9366 non-null   float64
#  12  INSEGURIDAD               9366 non-null   float64
# ...

# %%
upz = pd.read_csv('/content/drive/MyDrive/Inmersión de datos/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor  Valor_millon  Valor_m_x_a  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Valor_millon              9318 non-null   float64
#  9   Valor_m_x_a               9318 non-null   float64
#  10  precio_m2_x_barrio        9318 non-null   float64
#  11  CONJUNTO_CERRADO          9318 non-null   float64
#  12  INSEGURIDAD               9318 non-null   float64
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Valor_millon')
plt.show()

# %%
datos_ml.query('Valor_millon > 5000 | Valor_millon < 60')
# Out:
# Empty DataFrame
# Columns: [Tipo, Descripcion, Habitaciones, Banos, Area, Barrio, UPZ, Valor, Valor_millon, Valor_m_x_a, precio_m2_x_barrio, CONJUNTO_CERRADO, INSEGURIDAD, TERMINALES_BUS, BARES_DISCO, RUIDO, OSCURO_PELIGROSO, SALARIO_MES, TIENE_ESCRITURA, PERDIDA_TRABAJO_C19, PERDIDA_INGRESOS_C19, PLANES_ADQUIRIR_VIVIENDA, NOMBRE_ESTRATO, COD_UPZ_GRUPO, SALARIO_ANUAL_MI]
# Index: []
#
# [0 rows x 25 columns]

# %%
datos_ml = datos_ml.query('Valor_millon < 1200 & Valor_millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Valor_millon')
plt.show()

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# <ipython-input-125-71287e70a4cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI',y ='Valor_m_x_a')
plt.ylim((0,15))
plt.show()

# %%
datos_ml.corr()
# Out:
#                           Habitaciones  Banos  Area  Valor_millon  \
# Habitaciones                      1.00   0.44  0.03          0.18
# Banos                             0.44   1.00  0.04          0.66
# Area                              0.03   0.04  1.00          0.04
# Valor_millon                      0.18   0.66  0.04          1.00
# Valor_m_x_a                      -0.31  -0.03 -0.04          0.36
# precio_m2_x_barrio               -0.21   0.13 -0.04          0.40
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01          0.32
# INSEGURIDAD                       0.13  -0.19 -0.00         -0.37
# TERMINALES_BUS                    0.08  -0.17 -0.01         -0.28
# BARES_DISCO                       0.11  -0.12 -0.01         -0.23
# RUIDO                             0.14  -0.17 -0.00         -0.35
# OSCURO_PELIGROSO                  0.11  -0.21  0.01         -0.38
# SALARIO_MES                      -0.17   0.18 -0.01          0.42
# ...

# %%
#Se crea un mapa de calor utilizando la correlación de los datos de datos_ml, se establece el valor min y max, annot=True hace que se vean los números en las celdas y cmap establece la gama de colores
plt.figure(figsize=(18, 8))
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# %%
#Se importan las bibliotecas necesarias para la regresión lineal y la división de parámentros de entrenamiento y prueba
#COD_UPZ se establece como la variable independiente y valor_millon como la dependiente (valor_millon es lo que queremos predecir)
#test_size le dice con cuantos datos entrena y random state es para poder reproducirlo (que trabaje con los mismos datos)

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Valor_millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)

# %%
X_train
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
X_test
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Valor_millon, Length: 6234, dtype: float64

# %%
y_test
# Out:
# 6340   199.90
# 7805   120.80
# 4902   400.00
# 7041   340.00
# 2436   355.00
#         ...
# 3323   700.00
# 3945   510.00
# 5572   220.00
# 3633   420.00
# 3652   435.60
# Name: Valor_millon, Length: 2079, dtype: float64

# %%
modelo = LinearRegression()

# %%
#Se entrena el modelo (Machine Learning)
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Se guarda la predicción del modelo en una variable para su análisis eeficacia
y_predict_test = modelo.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %%
#Se vuelve a entrenar nuestro modelo pero tomando más variables para su predicción, aumentando la eficacia

X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] 

y = datos_ml["Valor_millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988
